# %%
# %load_ext autoreload
# %autoreload 2

import util
import config

project_id = 119867
pool_id = 36425808
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
url = 'api/v1/task-suites?async_mode=false&open_pool=true'

# %%
import random
from tqdm.auto import tqdm

# %%
url = 'api/v1/task-suites?async_mode=true&open_pool=true'

# %%
for _ in range(100):
    suites = []

    for i in range(10):
        ID = random.randint(1, 50000)
        data = {
            'pool_id': pool_id,
            'tasks': [{'input_values': {'id': ID}}],
            "overlap": 1,
        }
        suites.append(data)

    resp = util.toloka_post(url, suites)
    print(resp)
    # resp.json()
# Out:
# <Response [202]>
# <Response [202]>
# <Response [202]>
# <Response [202]>
# <Response [202]>
# <Response [202]>
# <Response [202]>
# <Response [202]>
# <Response [202]>
# <Response [202]>
# <Response [202]>
# <Response [202]>
# <Response [202]>
# <Response [202]>
# <Response [202]>
# <Response [202]>
# <Response [202]>
# <Response [202]>
# <Response [202]>
# <Response [202]>
# <Response [202]>
# <Response [202]>
# <Response [202]>
# <Response [202]>
# <Response [202]>
# <Response [202]>
# <Response [202]>
# <Response [202]>
# <Response [202]>
# <Response [202]>
# <Response [202]>
# <Response [202]>
# <Response [202]>
# <Response [202]>
# <Response [202]>
# <Response [202]>
# <Response [202]>
# <Response [202]>
# <Response [202]>
# <Response [202]>
# <Response [202]>
# <Response [202]>
# <Response [202]>
# <Response [202]>
# <Response [202]>
# <Response [202]>
# <Response [202]>
# <Response [202]>
# <Response [202]>
# <Response [202]>
# <Response [202]>
# <Response [202]>
# ...

# %%
# Out:
# <Response [504]>
